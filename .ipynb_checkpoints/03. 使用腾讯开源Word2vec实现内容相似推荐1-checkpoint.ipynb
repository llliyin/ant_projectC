# %% [markdown]
# ## 使用腾讯开源Word2vec实现内容相似推荐
#
# 下载地址：https://ai.tencent.com/ailab/nlp/embedding.html
#
# 数据格式：
# * 下载后解压文件名为Tencent_AILab_ChineseEmbedding.txt
# * 第一行是8824330 200，即行数和维度数
# * 之后的每行，用空格分隔201列，其中第一个是词语，后面是Embedding
#
#
# 实现步骤：
# 1. 获取文章列表数据，包括ID、标题、内容
# 2. 使用jieba实现关键词提取
# 3. 查询腾讯word2vec，平均法得到文档embedding
# 4. 对于输入的ID，计算最相似的文章列表

# %% [markdown]
# ### 1. 获取数据

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("./datas/questions_wordsegs.csv")
df.head()
# Out:
#    id          试卷名称                                 试题简介  \
# 0   0  第1节　长度和时间的测量                   (柳州中考)一个中学生的身高约为()
# 1   1  第1节　长度和时间的测量                       下列长度单位换算正确的是()
# 2   2  第1节　长度和时间的测量  初中生小红想对比测量一个月前后自己的身高变化,选用下列哪种尺最合适()
# 3   3  第1节　长度和时间的测量                 如图所示测量木块长度的方法中正确的是()
# 4   4  第1节　长度和时间的测量                下列各个过程中经历的时间最接近1秒的是()
#
#                                                words
# 0                           长度 时间 测量 柳州 中考 一个 中学生 身高
# 1                            长度 时间 测量 下列 长度 单位 换算 正确
# 2  长度 时间 测量 初中生 小红想 对比 测量 一个月 前后 自己 身高 变化 选用 下列 哪...
# 3                       长度 时间 测量 如图所示 测量 木块 长度 方法 正确
# 4                         长度 时间 测量 下列 各个 过程 经历 时间 接近

# %% [markdown]
# ### 2. 查询腾讯数据集计算文档Embedding

# %% [markdown]
# #### 去重后的词表

# %%
all_words = set()
for idx, row in df.iterrows():
    all_words.update(row["words"].split())
len(all_words)
# Out:
# 3024

# %% [markdown]
# #### 查询候选词语的腾讯wordEmbedding

# %%
# 候选词语的embedding
word_embedding = {}

is_first_line = True
# with open("/home/pss/windir/Tencent_AILab_ChineseEmbedding.txt") as fin:
with open("./datas/small_tencent_embedding.txt",encoding='utf-8') as fin:
    for line in fin:
        if is_first_line: 
            is_first_line = False
            continue
        fields = line[:-1].split()
        if len(fields) != 201:
            continue
        word = fields[0]
        if word in all_words:
            word_embedding[word] = np.array([float(x) for x in fields[1:]])

# %%
print(len(word_embedding), word_embedding["长度"])
# Out:
# 985 [ 0.005834 -0.395921 -0.180423  0.296069  0.052518 -0.054451  0.020149
#  -0.044086  0.353312 -0.22374  -0.04508   0.055951 -0.174403  0.155743
#  -0.012774 -0.074717  0.179427  0.190087  0.261729 -0.077895 -0.238144
#   0.034836  0.179018  0.335313 -0.058311  0.170257 -0.093793  0.013557
#   0.109592  0.511844  0.088042 -0.580139 -0.017787  0.020833 -0.110023
#  -0.152744  0.575039  0.237301 -0.211268 -0.27189   0.730821 -0.046814
#   0.93922   0.121126 -0.032281 -0.036091 -0.39794  -0.648644 -0.213008
#   0.147335 -0.44408   0.079484 -0.514313  0.004092  0.105224 -0.060358
#  -0.288678 -0.019406  0.138733 -0.069249 -0.069714  0.436858 -0.143623
#   0.075708  0.35814  -0.335786 -0.087457  0.114769  0.047824  0.135914
#   0.114568 -0.082952  0.275859  0.377795  0.264313  0.042248  0.153559
#   0.165835  0.181142  0.088547 -0.008424  0.361963 -0.026601  0.647748
#   0.278543 -1.1967   -0.372485  0.074411 -0.282418 -0.880456  0.279597
#   0.331155  0.167894 -0.101904  0.087408  0.250657  0.094835 -0.115425
#   0.189007 -0.063402 -0.131974  0.314448  0.137707  0.125536  0.028432
#   0.488391 -0.199801 -0.175716  0.632639 -0.038522 -0.197321 -0.12904
#  -0.324929 -0.291432 -0.169884  0.161303 -0.132168 -0.384981  0.092519
#  -0.075655  0.12461  -0.170697 -0.060894  0.079161  0.271918  0.323061
#   0.003104  0.27705  -0.249535  0.166044 -0.116533  0.148693  0.139172
#  -0.334214 -0.277468 -0.276875 -0.460363 -0.261124 -0.295192  0.132843
#   0.301913 -0.101141 -0.071624 -0.161329 -0.142853  0.386341 -0.090005
#  -0.066     0.230321  0.293398 -0.235417 -0.249791  0.535728 -0.311841
#  -0.1172    0.012212 -0.059069  0.641881  0.3035   -0.235848  0.235497
#  -0.005008 -0.102879  0.369235 -0.12926  -0.08129  -0.487524 -0.262114
#   0.171527 -0.147099 -0.093734  0.062083 -0.134804  0.230383 -0.282632
#   0.490883  0.001818  0.218216  0.16602  -0.151525 -0.198294 -0.414007
#  -0.093273 -0.668659 -0.630978  0.030093 -0.175079  0.387142 -0.217619
#   0.015008  0.054933 -0.13605   0.304182 -0.214507  0.134545 -0.277078
#   0.1238   -0.019482  0.231154 -0.11518 ]

# %% [markdown]
# #### 计算每篇文章的doc embedding

# %%
def compute_doc_vector(words):
    words = words.split()
    embeddings = []
    for word in words:
        if word in word_embedding:
            embeddings.append(word_embedding[word])
    return np.sum(embeddings, axis=0) / len(embeddings)

df["doc_vector"] = df["words"].map(compute_doc_vector)
# Out:
# C:\ProgramData\Anaconda3\envs\dlsys1\lib\site-packages\ipykernel_launcher.py:7: RuntimeWarning: invalid value encountered in double_scalars
#   import sys

# %%
df.head(3)
# Out:
#    id          试卷名称                                 试题简介  \
# 0   0  第1节　长度和时间的测量                   (柳州中考)一个中学生的身高约为()
# 1   1  第1节　长度和时间的测量                       下列长度单位换算正确的是()
# 2   2  第1节　长度和时间的测量  初中生小红想对比测量一个月前后自己的身高变化,选用下列哪种尺最合适()
#
#                                                words  \
# 0                           长度 时间 测量 柳州 中考 一个 中学生 身高
# 1                            长度 时间 测量 下列 长度 单位 换算 正确
# 2  长度 时间 测量 初中生 小红想 对比 测量 一个月 前后 自己 身高 变化 选用 下列 哪...
#
#                                           doc_vector
# 0  [0.10882925, -0.372443, -0.08033349999999999, ...
# 1  [0.043941400000000005, -0.26982680000000003, -...
# 2  [0.10865833333333334, -0.28194566666666665, -0...

# %% [markdown]
# ### 4. 对于给定文章算出最相似的10篇文章

# %%
# 随便挑选一篇文章ID，2583：pandas，581：PHP
article_id = 258
df.loc[df["id"]==article_id]
# Out:
#       id                    试卷名称  \
# 258  258  09月30日物理课堂练习201改练声音的产生
#
#                                                   试题简介  \
# 258  (随州中考)如图所示,在探究“声音是由物体振动产生的”实验中,将正在发声的音叉紧靠悬线下的轻...
#
#                                                  words  \
# 258  09 30 物理 课堂练习 201 改练 声音 产生 随州 中考 如图所示 探究 声音 物体...
#
#                                             doc_vector
# 258  [0.17574740000000003, -0.1689654, -0.191655599...

# %%
article_embedding = df.loc[df["id"]==article_id, "doc_vector"].iloc[0]
article_embedding
# Out:
# array([ 1.757474e-01, -1.689654e-01, -1.916556e-01,  7.697020e-02,
#         8.083090e-02, -3.556480e-02,  7.456410e-02,  1.847721e-01,
#         1.373630e-01,  3.422919e-01,  1.197105e-01,  4.723310e-02,
#        -2.157270e-02, -4.279760e-02, -1.235848e-01,  2.178100e-03,
#         1.773750e-01, -1.880477e-01, -1.122771e-01, -6.640790e-02,
#        -1.180276e-01,  2.561470e-02,  1.687922e-01,  1.073239e-01,
#         4.881600e-03,  6.730250e-02, -1.060451e-01,  6.912790e-02,
#         1.038758e-01,  5.721760e-02,  6.908920e-02,  1.283737e-01,
#        -4.925550e-02,  8.439820e-02, -8.146040e-02, -2.198169e-01,
#         2.186135e-01,  9.345570e-02, -1.861646e-01,  9.296130e-02,
#         2.277380e-02,  8.393710e-02,  4.866047e-01,  1.703435e-01,
#         6.107210e-02, -5.514660e-02, -1.570685e-01, -3.874890e-01,
#         1.479703e-01, -6.045800e-02, -1.350433e-01,  1.517390e-02,
#        -1.970015e-01,  4.580400e-02,  1.030453e-01,  5.889720e-02,
#         1.993840e-02,  4.998580e-02,  8.964660e-02, -1.677578e-01,
#         5.895950e-02,  3.108844e-01,  1.740962e-01, -1.123350e-01,
#        -1.983714e-01, -4.967010e-02,  3.948020e-02,  7.078110e-02,
#        -1.937183e-01, -6.576950e-02, -1.338510e-01,  2.180278e-01,
#         1.874861e-01,  2.077711e-01, -2.945184e-01,  2.066611e-01,
#         1.677240e-01,  2.166607e-01,  1.131537e-01, -5.368240e-02,
#         1.446355e-01,  2.223060e-01, -2.875190e-02,  2.622938e-01,
#         2.079860e-01, -2.488101e-01, -2.097360e-01,  5.631240e-02,
#        -3.241031e-01, -3.090580e-01,  1.790036e-01, -1.183999e-01,
#        -7.710950e-02, -1.712691e-01,  2.217050e-02,  1.041385e-01,
#         1.001580e-02, -5.116050e-02, -2.050233e-01, -8.786310e-02,
#        -1.802798e-01,  1.389825e-01, -9.575280e-02,  8.423250e-02,
#        -1.987490e-01,  9.333820e-02,  4.038600e-03, -4.379782e-01,
#         3.592380e-02,  4.066560e-02, -6.457130e-02,  2.138220e-02,
#         1.535590e-02, -2.264310e-01, -8.394480e-02, -8.363700e-02,
#         3.173910e-02, -1.027127e-01, -1.143367e-01, -2.633162e-01,
#         1.263079e-01, -3.212593e-01, -6.693880e-02,  2.767840e-02,
#         1.055217e-01,  2.225937e-01, -1.614050e-01,  1.102118e-01,
#        -6.297520e-02,  2.343177e-01, -1.112450e-02,  3.253000e-04,
#         2.820675e-01, -3.204027e-01, -2.719042e-01, -2.311126e-01,
#        -1.050444e-01, -1.431726e-01, -7.708300e-03,  6.398140e-02,
#        -1.257075e-01, -2.994437e-01, -3.013206e-01, -1.624672e-01,
#         1.707140e-02, -1.171418e-01,  1.230299e-01,  1.081152e-01,
#         4.981530e-02, -5.096680e-02, -3.919870e-02, -4.313430e-02,
#         5.033460e-02, -9.912480e-02, -1.570073e-01,  8.737600e-02,
#         1.616575e-01,  1.436717e-01,  2.842041e-01, -7.218670e-02,
#         4.045098e-01, -1.942153e-01, -9.147520e-02,  2.196763e-01,
#         9.501260e-02, -1.223638e-01, -2.495833e-01,  1.414107e-01,
#         1.711057e-01, -1.666138e-01, -1.319656e-01,  5.984640e-02,
#        -6.185810e-02,  2.682638e-01, -3.338610e-02, -1.167796e-01,
#        -1.357032e-01,  1.441782e-01, -4.317850e-02,  1.849167e-01,
#        -1.614577e-01, -9.164620e-02, -3.080560e-02,  1.227539e-01,
#        -3.952700e-03,  1.248992e-01, -1.438217e-01,  1.618123e-01,
#         7.926150e-02,  1.899142e-01,  3.324039e-01,  1.399422e-01,
#         2.553016e-01,  9.161210e-02,  1.776402e-01,  2.358306e-01,
#        -3.491250e-02, -1.186050e-01, -2.135525e-01,  6.419690e-02])

# %%
# 余弦相似度
from scipy.spatial import distance
df["sim_value"] = df["doc_vector"].map(lambda x : 1 - distance.cosine(article_embedding, x))

# %%
df[["id", "试卷名称","试题简介", "sim_value"]].head(3)
# Out:
#    id          试卷名称                                 试题简介  sim_value
# 0   0  第1节　长度和时间的测量                   (柳州中考)一个中学生的身高约为()   0.629796
# 1   1  第1节　长度和时间的测量                       下列长度单位换算正确的是()   0.679925
# 2   2  第1节　长度和时间的测量  初中生小红想对比测量一个月前后自己的身高变化,选用下列哪种尺最合适()   0.733528

# %%
# 按相似度降序排列，查询前10条
df.sort_values(by="sim_value", ascending=False)[["id", "试卷名称","试题简介", "sim_value"]].head(20)
# Out:
#         id                        试卷名称  \
# 258    258      09月30日物理课堂练习201改练声音的产生
# 163    163          09月22日物理课堂练习声音的产生1
# 154    154                第1节　声音的产生与传播
# 161    161          09月22日物理课堂练习声音的产生1
# 160    160          09月22日物理课堂练习声音的产生1
# 261    261      09月30日物理课堂练习201改练声音的产生
# 167    167          09月22日物理课堂练习声音的产生2
# 1349  1349               20年11月18日物理练习
# 1306  1306               20年11月17日物理练习
# 1068  1068               20年11月05日物理练习
# 1410  1410               20年11月25日物理练习
# 128    128        09月21日物理课堂练习104测平均速度
# 266    266      09月30日物理课堂练习201改练声音的产生
# 208    208               20年09月29日物理练习
# 159    159          09月22日物理课堂练习声音的产生1
# 1481  1481             12月15日物理课堂练习视频1
# 267    267      09月30日物理课堂练习201改练声音的产生
# 1535  1535               20年12月10日物理练习
# 1305  1305               20年11月17日物理练习
# 1495  1495  12月15日物理课堂练习凸透镜成像实验2（实验过程）
#
#                                                    试题简介  sim_value
# 258   (随州中考)如图所示,在探究“声音是由物体振动产生的”实验中,将正在发声的音叉紧靠悬线下的轻...   1.000000
# 163   如图所示,用悬挂着的乒乓球接触正在发声的音叉,乒乓球会多次被弹开.这个实验是用来探究(     )   0.958562
# 154   (随州中考)如图所示,在探究“声音是由物体振动产生的”实验中,将正在发声的音叉紧靠悬线下的轻...   0.958414
# 161   如图所示,用悬挂着的乒乓球接触正在发声的音叉,乒乓球被弹开.这个实验是我们在学习«声现象»一...   0.956020
# 160   在探究人耳怎样听到声音时,可以用肥皂膜模拟人耳的鼓膜.如图所示,当喇叭发声时,肥皂膜将(    )   0.945184
# 261   小提琴声是通过琴弓与琴弦的摩擦使琴弦振动(如图所示),琴弦将振动传递给木质的琴码和琴箱,再使...   0.936723
# 167   使正在发声的音叉接触水面,水面溅起水花,说明声音是由物体的  产生的.锣发声的时候,用手 按...   0.931543
# 1349  (光反实验现象)如图所示是小明同学探究反射定律的实验装置。  (1)若转动F半面时,上面（可...   0.930772
# 1306  (光反实验现象)如图所示是小明同学探究反射定律的实验装置。  (1)若转动F半面时,上面（可...   0.930377
# 1068  (19武汉)在“探究水沸腾时温度变化的特点”的实验中,某组同学用如图甲所示实验装置进行了两次...   0.929054
# 1410  (改编于2019武汉)在“探究水沸腾时温度变化的特点”的实验中,某组同学用如图甲所示实验装置...   0.927648
# 128   两个同学做“探究小车沿斜面下滑时速度变化的情况”实验,如图所示是小车滑下过程中的示意图,实验...   0.927578
# 266                                下列最能说明液体可以传播声音的现象是()   0.926786
# 208   使正在发声的音叉接触水面,水面溅起水花,说明声音是由物体的  产生的.锣发声的时候,用手 按...   0.924607
# 159                           如图所示,关于声现象的各种实验中,下列说法正确的是   0.923503
# 1481  如图为研究凸透镜成像的实验,在实验中发现无论如何调整光屏的位置,都不能在光屏上找到蜡烛的像,...   0.922576
# 267   如图所示的现象说明了_______,物理学中把这种研究问题的方法叫做_______法. 敲鼓...   0.922169
# 1535   某同学为进一步了解“视力矫正”的原理,利用探究凸透镜成像规律的装置做了实验。他在发光体和凸...   0.922030
# 1305  (19武汉)在“探究水沸腾时温度变化的特点”的实验中,某组同学用如图甲所示实验装置进行了两次...   0.920791
# 1495  小林同学做“探究凸透镜成像规律”的实验中,蜡烛、凸透镜、光屏在光具座上的位置如图所示,这时烛...   0.919974
